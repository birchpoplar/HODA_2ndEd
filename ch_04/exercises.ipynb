# %% [markdown]
# # Exercise 1

# %%
import pandas as pd
import numpy as np

earthquakes = pd.read_csv('exercises/earthquakes.csv')
earthquakes.head()
# Out:
#     mag magType           time                  place  tsunami parsed_place
# 0  1.35      ml  1539475168010  9km NE of Aguanga, CA        0   California
# 1  1.29      ml  1539475129610  9km NE of Aguanga, CA        0   California
# 2  3.42      ml  1539475062610  8km NE of Aguanga, CA        0   California
# 3  0.44      ml  1539474978070  9km NE of Aguanga, CA        0   California
# 4  2.16      md  1539474716050  10km NW of Avenal, CA        0   California

# %%
eq_jp_4pt9 = earthquakes.query('parsed_place == "Japan" and magType == "mb" and mag >= 4.9')
eq_jp_4pt9.head()
# Out:
#       mag magType           time                         place  tsunami  \
# 1563  4.9      mb  1538977532250  293km ESE of Iwo Jima, Japan        0
# 2576  5.4      mb  1538697528010    37km E of Tomakomai, Japan        0
# 3072  4.9      mb  1538579732490     15km ENE of Hasaki, Japan        0
# 3632  4.9      mb  1538450871260    53km ESE of Hitachi, Japan        0
#
#      parsed_place
# 1563        Japan
# 2576        Japan
# 3072        Japan
# 3632        Japan

# %% [markdown]
# # Exercise 2

# %%
earthquakes.describe()
# Out:
#                mag          time      tsunami
# count  9331.000000  9.332000e+03  9332.000000
# mean      1.497345  1.538284e+12     0.006537
# std       1.203347  6.080306e+08     0.080589
# min      -1.260000  1.537229e+12     0.000000
# 25%       0.720000  1.537793e+12     0.000000
# 50%       1.300000  1.538245e+12     0.000000
# 75%       1.900000  1.538766e+12     0.000000
# max       7.500000  1.539475e+12     1.000000

# %%
eq_mltype = earthquakes[earthquakes.magType == 'ml']
eq_mltype.head()
# Out:
#     mag magType           time                         place  tsunami  \
# 0  1.35      ml  1539475168010         9km NE of Aguanga, CA        0
# 1  1.29      ml  1539475129610         9km NE of Aguanga, CA        0
# 2  3.42      ml  1539475062610         8km NE of Aguanga, CA        0
# 3  0.44      ml  1539474978070         9km NE of Aguanga, CA        0
# 6  1.70      ml  1539473176017  105km W of Talkeetna, Alaska        0
#
#   parsed_place
# 0   California
# 1   California
# 2   California
# 3   California
# 6       Alaska

# %%
eq_binned = pd.cut(eq_mltype.mag, bins = list(range(0,9)))
eq_binned.value_counts()
# Out:
# (1, 2]    3105
# (0, 1]    2207
# (2, 3]     862
# (3, 4]     122
# (4, 5]       2
# (5, 6]       1
# (6, 7]       0
# (7, 8]       0
# Name: mag, dtype: int64

# %% [markdown]
# # Exercise 3

# %%
faang = pd.read_csv('exercises/faang.csv')
faang.head()
# Out:
#   ticker        date        high         low        open       close  \
# 0     FB  2018-01-02  181.580002  177.550003  177.679993  181.419998
# 1     FB  2018-01-03  184.779999  181.330002  181.880005  184.669998
# 2     FB  2018-01-04  186.210007  184.100006  184.899994  184.330002
# 3     FB  2018-01-05  186.899994  184.929993  185.589996  186.850006
# 4     FB  2018-01-08  188.899994  186.330002  187.199997  188.279999
#
#        volume
# 0  18151900.0
# 1  16886600.0
# 2  13880900.0
# 3  13574500.0
# 4  17994700.0

# %%
faang.dtypes
# Out:
# ticker     object
# date       object
# high      float64
# low       float64
# open      float64
# close     float64
# volume    float64
# dtype: object

# %%
faang.loc[:,'date'] = pd.to_datetime(faang.date)

# %%
faang.dtypes
# Out:
# ticker            object
# date      datetime64[ns]
# high             float64
# low              float64
# open             float64
# close            float64
# volume           float64
# dtype: object

# %%
faang = faang.set_index('date')

# %%
faang.groupby('ticker').resample('1M').agg({'open': 'mean', 'high': 'max', 'low': 'min', 'close': 'mean', 'volume': 'sum'})
# Out:
#                           open         high          low        close  \
# ticker date
# AAPL   2018-01-31    43.505357    45.025002    41.174999    43.501309
#        2018-02-28    41.819079    45.154999    37.560001    41.909737
#        2018-03-31    43.761786    45.875000    41.235001    43.624048
#        2018-04-30    42.441310    44.735001    40.157501    42.458572
#        2018-05-31    46.239091    47.592499    41.317501    46.384205
#        2018-06-30    47.180119    48.549999    45.182499    47.155357
#        2018-07-31    47.549048    48.990002    45.855000    47.577857
#        2018-08-31    53.121739    57.217499    49.327499    53.336522
#        2018-09-30    55.582763    57.417500    53.825001    55.518421
#        2018-10-31    55.300000    58.367500    51.522499    55.211413
#        2018-11-30    47.954881    55.590000    42.564999    47.808929
#        2018-12-31    41.310789    46.235001    36.647499    41.066579
# ...

# %%
faang.head()
# Out:
#            ticker        high         low        open       close      volume
# date
# 2018-01-02     FB  181.580002  177.550003  177.679993  181.419998  18151900.0
# 2018-01-03     FB  184.779999  181.330002  181.880005  184.669998  16886600.0
# 2018-01-04     FB  186.210007  184.100006  184.899994  184.330002  13880900.0
# 2018-01-05     FB  186.899994  184.929993  185.589996  186.850006  13574500.0
# 2018-01-08     FB  188.899994  186.330002  187.199997  188.279999  17994700.0

# %%
faang.head()
# Out:
#   ticker       date        high         low        open       close  \
# 0     FB 2018-01-02  181.580002  177.550003  177.679993  181.419998
# 1     FB 2018-01-03  184.779999  181.330002  181.880005  184.669998
# 2     FB 2018-01-04  186.210007  184.100006  184.899994  184.330002
# 3     FB 2018-01-05  186.899994  184.929993  185.589996  186.850006
# 4     FB 2018-01-08  188.899994  186.330002  187.199997  188.279999
#
#        volume
# 0  18151900.0
# 1  16886600.0
# 2  13880900.0
# 3  13574500.0
# 4  17994700.0

# %% [markdown]
# # Exercise 4

# %%
pd.crosstab(index=earthquakes.tsunami, columns=earthquakes.magType, values=earthquakes.mag, aggfunc=np.max)
# Out:
# magType   mb  mb_lg    md   mh   ml  ms_20    mw  mwb  mwr  mww
# tsunami
# 0        5.6    3.5  4.11  1.1  4.2    NaN  3.83  5.8  4.8  6.0
# 1        6.1    NaN   NaN  NaN  5.1    5.7  4.41  NaN  NaN  7.5

# %% [markdown]
# # Exercise 5

# %%
faang.head()
# Out:
#            ticker        high         low        open       close      volume
# date
# 2018-01-02     FB  181.580002  177.550003  177.679993  181.419998  18151900.0
# 2018-01-03     FB  184.779999  181.330002  181.880005  184.669998  16886600.0
# 2018-01-04     FB  186.210007  184.100006  184.899994  184.330002  13880900.0
# 2018-01-05     FB  186.899994  184.929993  185.589996  186.850006  13574500.0
# 2018-01-08     FB  188.899994  186.330002  187.199997  188.279999  17994700.0

# %%
faang.groupby('ticker').rolling('60D').agg({'open': 'mean', 'high': 'max', 'low': 'min', 'close': 'mean', 'volume': 'sum'})
# Out:
#                          open        high         low       close       volume
# ticker date
# AAPL   2018-01-02   42.540001   43.075001   42.314999   43.064999  102223600.0
#        2018-01-03   42.836250   43.637501   42.314999   43.061249  220295200.0
#        2018-01-04   42.935833   43.637501   42.314999   43.126666  310033600.0
#        2018-01-05   43.041875   43.842499   42.314999   43.282499  404673600.0
#        2018-01-08   43.151000   43.902500   42.314999   43.343500  486944800.0
# ...                       ...         ...         ...         ...          ...
# NFLX   2018-12-24  283.509251  332.049988  233.679993  281.931750  525657600.0
#        2018-12-26  281.844501  332.049988  231.229996  280.777750  520444300.0
#        2018-12-27  281.070489  332.049988  231.229996  280.162927  532679500.0
#        2018-12-28  279.916342  332.049988  231.229996  279.461464  521973500.0
#        2018-12-31  278.430770  332.049988  231.229996  277.451539  476314900.0
#
# ...

# %% [markdown]
# # Exercise 6

# %%
faang.pivot_table(index='ticker')
# Out:
#               close         high          low         open        volume
# ticker
# AAPL      47.263357    47.748526    46.795877    47.277859  1.360803e+08
# AMZN    1641.726176  1662.839839  1619.840519  1644.072709  5.648994e+06
# FB       171.510956   173.613347   169.303148   171.472948  2.765860e+07
# GOOG    1113.225134  1125.777606  1101.001658  1113.554101  1.741965e+06
# NFLX     319.290319   325.219322   313.187330   319.620558  1.146962e+07

# %% [markdown]
# # Exercise 7

# %%
from sklearn.preprocessing import scale
faang.loc['2018-q4'].query('ticker=="AMZN"').drop(columns='ticker').apply(lambda V: scale(V,axis=0,with_mean=True, with_std=True,copy=False),axis=1)
# Out:
# date
# 2018-10-01    [-0.499987418627928, -0.5000088080314785, -0.4...
# 2018-10-02    [-0.49998806426968606, -0.5000101158218525, -0...
# 2018-10-03    [-0.4999899033724807, -0.5000088944663621, -0....
# 2018-10-04    [-0.4999902645537058, -0.5000107433482791, -0....
# 2018-10-05    [-0.4999892995562591, -0.5000135833222057, -0....
#                                     ...
# 2018-12-24    [-0.4999834516878023, -0.5000142850180227, -0....
# 2018-12-26    [-0.4999869913145524, -0.5000134432821367, -0....
# 2018-12-27    [-0.49999351566315053, -0.5000137536875198, -0...
# 2018-12-28    [-0.49999008498333675, -0.5000083432142597, -0...
# 2018-12-31    [-0.49999438101357835, -0.5000065196712391, -0...
# Length: 63, dtype: object

# %%
faang.head()
faang.loc['2018-q4']
# Out:
#            ticker         high          low         open        close  \
# date
# 2018-10-01     FB   165.880005   161.259995   163.029999   162.440002
# 2018-10-02     FB   162.279999   158.669998   161.580002   159.330002
# 2018-10-03     FB   163.660004   159.529999   160.000000   162.429993
# 2018-10-04     FB   161.460007   157.350006   161.460007   158.850006
# 2018-10-05     FB   160.899994   156.199997   159.210007   157.330002
# ...           ...          ...          ...          ...          ...
# 2018-12-24   GOOG  1003.539978   970.109985   973.900024   976.219971
# 2018-12-26   GOOG  1040.000000   983.000000   989.010010  1039.459961
# 2018-12-27   GOOG  1043.890015   997.000000  1017.150024  1043.880005
# 2018-12-28   GOOG  1055.560059  1033.099976  1049.619995  1037.079956
# 2018-12-31   GOOG  1052.699951  1023.590027  1050.959961  1035.609985
#
#                 volume
# date
# 2018-10-01  26407700.0
# 2018-10-02  36031000.0
# 2018-10-03  23109500.0
# ...
